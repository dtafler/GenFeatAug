# %%
import torch
import matplotlib.pyplot as plt

cvae_latents = torch.load('cvae_latent/cvae_latents.pt').cpu().detach() # shape (10000, 2)
vae_latents = torch.load('cvae_latent/vae_latents.pt').cpu().detach() # shape (10000, 2)
labels = torch.load('cvae_latent/labels.pt').cpu().detach() # shape 10000


plt.rc('font', family='serif')
plt.rc('font', serif='DejaVu Serif')
plt.rc('text', usetex=False)  # Disable LaTeX

fig_width_pt = 425.196 * 1
fig_width_in = fig_width_pt / 72.27
# fig_height_in = fig_width_in / 1.618  # Optional: Use the golden ratio for height
fig_height_in = fig_width_in * 0.6


# Define colors and markers for the 10 classes
colors = plt.cm.get_cmap('tab10', 10)
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', 'P', '*']

# Create a figure with two subplots
# fig, axs = plt.subplots(1, 2, figsize=(14, 7), sharex=False, sharey=True)
fig, axs = plt.subplots(1, 2, figsize=(fig_width_in, fig_height_in), sharex=False, sharey=True)


# Plot VAE latents
for i in range(10):
    idx = labels == i
    axs[0].scatter(vae_latents[idx, 0], vae_latents[idx, 1], color=colors(i), marker=markers[i], label=f'Class {i}', alpha=0.6, edgecolors='w', linewidth=0.5)
axs[0].set_title('VAE', fontsize=16)
axs[0].set_xlabel('Latent Dimension 1', fontsize=14)
axs[0].set_ylabel('Latent Dimension 2', fontsize=14)
axs[0].tick_params(axis='both', which='major', labelsize=12)

# Plot CVAE latents
for i in range(10):
    idx = labels == i
    axs[1].scatter(cvae_latents[idx, 0], cvae_latents[idx, 1], color=colors(i), marker=markers[i], label=f'Class {i}', alpha=0.6, edgecolors='w', linewidth=0.5)
axs[1].set_title('CVAE', fontsize=16)
axs[1].set_xlabel('Latent Dimension 1', fontsize=14)
# axs[1].set_ylabel('Latent Dimension 2', fontsize=14)
axs[1].tick_params(axis='both', which='major', labelsize=12)

# Ensure the same scale for both plots
axs[0].set_xlim(-1, 2)
axs[0].set_ylim(-2, 2)
axs[1].set_xlim(-2, 2)
axs[1].set_ylim(-2, 2)

# Set x-ticks and y-ticks to show only integers
axs[0].xaxis.set_major_locator(plt.MaxNLocator(integer=True))
axs[0].yaxis.set_major_locator(plt.MaxNLocator(integer=True))
axs[1].xaxis.set_major_locator(plt.MaxNLocator(integer=True))
axs[1].yaxis.set_major_locator(plt.MaxNLocator(integer=True))

# Improve legend
handles, labels = axs[1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center left', bbox_to_anchor=(0.9, 0.5), ncol=1, fontsize=12, frameon=False)

# Style the plot
plt.tight_layout(rect=[0, 0, 0.9, 0.9])
# plt.savefig('latents.png', dpi=300)
plt.savefig('latents.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_4096331/2406871527.py:59: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', 10)

# %%
import torch
import matplotlib.pyplot as plt

cvae_latents = torch.load('cvae_latent/cvae_latents.pt').cpu().detach()  # shape (10000, 2)
vae_latents = torch.load('cvae_latent/vae_latents.pt').cpu().detach()    # shape (10000, 2)
labels = torch.load('cvae_latent/labels.pt').cpu().detach()              # shape 10000

# Configure Matplotlib to use DejaVu Serif
plt.rc('font', family='serif')
plt.rc('font', serif='DejaVu Serif')
plt.rc('text', usetex=False)  # Disable LaTeX

# Define the figure width in points (1 * 15 cm in points)
fig_width_pt = 425.196
fig_width_in = fig_width_pt / 72.27
fig_height_in = fig_width_in * 0.65
# Set the individual plot dimensions
# plot_width_in = fig_width_in / 2
# plot_height_in = plot_width_in

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(fig_width_in, fig_height_in), sharex=False, sharey=True)

# Define colors and markers for the 10 classes
colors = plt.cm.get_cmap('tab10', 10)
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', 'P', '*']

# Plot VAE latents
for i in range(10):
    idx = labels == i
    axs[0].scatter(vae_latents[idx, 0], vae_latents[idx, 1], color=colors(i), marker=markers[i], label=f'Class {i}', alpha=0.6, edgecolors='w', linewidth=0.5)
axs[0].set_title('VAE', fontsize=12)
axs[0].set_xlabel('Dimension 1', fontsize=10)
axs[0].set_ylabel('Dimension 2', fontsize=10)
axs[0].tick_params(axis='both', which='major', labelsize=8)

# Plot CVAE latents
for i in range(10):
    idx = labels == i
    axs[1].scatter(cvae_latents[idx, 0], cvae_latents[idx, 1], color=colors(i), marker=markers[i], label=f'Class {i}', alpha=0.6, edgecolors='w', linewidth=0.5)
axs[1].set_title('CVAE', fontsize=12)
axs[1].set_xlabel('Dimension 1', fontsize=10)
# axs[1].set_ylabel('Latent Dimension 2', fontsize=12)
axs[1].tick_params(axis='both', which='major', labelsize=8)

# Ensure the same scale for both plots
axs[0].set_xlim(-3, 3)
axs[0].set_ylim(-3, 3)
axs[1].set_xlim(-3, 3)
axs[1].set_ylim(-3, 3)

# Set x-ticks and y-ticks to show only integers
axs[0].xaxis.set_major_locator(plt.MaxNLocator(integer=True))
axs[0].yaxis.set_major_locator(plt.MaxNLocator(integer=True))
axs[1].xaxis.set_major_locator(plt.MaxNLocator(integer=True))
axs[1].yaxis.set_major_locator(plt.MaxNLocator(integer=True))

# # Improve legend
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1), fontsize=10, ncol=5, frameon=True)
# Improve legend
# handles, labels = axs[1].get_legend_handles_labels()
# fig.legend(handles, labels, loc='center left', bbox_to_anchor=(0.9, 0.5), ncol=1, fontsize=10, frameon=True)

# Style the plot
plt.tight_layout(rect=[0, 0, 1, 0.88])
plt.savefig('latents.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_4096331/773882290.py:25: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', 10)
